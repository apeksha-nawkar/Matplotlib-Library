# %%
import pandas as pd
import matplotlib.pyplot as plt
x=pd.DataFrame(index=['name','phone','address','iohh'],data={'column1':['xuz','yush','yttsf','iotvbb'],'column2':[7,8,9,1]})
x
# Out:
#         column1  column2
# name        xuz        7
# phone      yush        8
# address   yttsf        9
# iohh     iotvbb        1

# %%
color=['.4','.8']
ax=x.plot.bar(color=['.5','.3'], figsize=(16,3))

# %%
ax=x.plot.box, figsize=(16,3)
ax
# Out:
# (16, 3)

# %%
# Out:
# (16, 3)

# %%
import seaborn as sns

# %%
tip=sns.load_dataset('tips')
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x='day', y='tip', hue='sex',data= tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(x='day', y='tip', data= tip)
# Out:
# C:\Users\Apeksha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Apeksha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day', y='tip', data= tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day', y='tip', data= tip)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
ax=x.plot.hist(color=['.5','.3'], figsize=(16,3))

# %%
ax=x.plot.kde(color=['.5','.3'], figsize=(16,3))

# %%
fig,(ax1,ax2,ax3,ax4,ax5,ax6)= plt.subplots(1,6, figsize=(12,4))
fig.suptitle("hello")
x.plot.line(ax=ax1, title='line plot')
x.plot.scatter(x='column1', y='column2',ax=ax2, title='scatter')
x.plot.bar(ax=ax3, title='bar')
x.plot.hist(ax=ax4, title='hist')
x.plot.box(ax=ax5, title='boxplot')
x.plot.kde(ax=ax6, title='kde')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9580/4031131887.py in <module>
#       7 x.plot.box(ax=ax5, title='boxplot')
#       8 x.plot.kde(ax=ax6, title='kde')
# ----> 9 x.sort_value("column2").plot.line(x="column1", y="column2",ax=ax1, title="lime")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'
